# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %%
flight_data = pd.read_csv('./dataset/merged_data/latter_flight_data.csv')
flight_data.head()
flight_data.shape
# Out:
#    DAY_OF_WEEK MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  ARR_DELAY  \
# 0            6                 WN                WN    MCO     -26.00
# 1            6                 UA                OO    ORD     -25.00
# 2            6                 B6                B6    MCO      22.00
# 3            6                 B6                B6    JFK      36.00
# 4            7                 B6                B6    JFK     -12.00
#
#           SCH_DEP_TIME         SCH_ARR_TIME  ORGIN_WTH_temp  ORGIN_WTH_precip  \
# 0  2022-01-01 10:30:00  2022-01-01 13:20:00           74.00              0.00
# 1  2022-01-01 10:40:00  2022-01-01 13:32:00           36.10              0.00
# 2  2022-01-01 13:13:00  2022-01-01 15:56:00           83.00              0.00
# 3  2022-01-01 21:45:00  2022-01-01 22:59:00           52.80              0.15
# 4  2022-01-02 08:29:00  2022-01-02 09:50:00           52.10              0.00
#
#    ORGIN_WTH_precipprob  ORGIN_WTH_snow  ORGIN_WTH_windspeed  \
# 0                     0            0.00                 6.90
# 1                     0            0.02                21.00
# 2                     0            0.00                 9.90
# 3                   100            0.00                 8.10
# 4                     0            0.00                 0.00
#
#    ORGIN_WTH_winddir  ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  \
# 0             200.00                  2.90                  9.90
# 1              20.00                100.00                  9.90
# 2             199.00                  4.30                  9.90
# 3              40.00                100.00                  2.20
# 4               0.00                100.00                  5.90
#
#    ORGIN_WTH_severerisk  DEST_WTH_temp  DEST_WTH_precip  DEST_WTH_precipprob  \
# 0                  3.00          48.00             0.00                    0
# 1                  3.00          47.90             0.00                    0
# 2                  3.00          47.70             0.00                    0
# 3                  3.00          37.90             0.02                  100
# 4                  3.00          25.00             0.00                    0
#
#    DEST_WTH_snow  DEST_WTH_windspeed  DEST_WTH_winddir  DEST_WTH_cloudcover  \
# 0           0.00                3.60              8.00               100.00
# 1           0.00                0.40            358.00               100.00
# 2           0.00                7.90            311.00               100.00
# 3           0.00                6.10            303.00               100.00
# 4           0.01               13.80            303.00               100.00
#
#    DEST_WTH_visibility  DEST_WTH_severerisk FORMER_FLIGHT_STATUS
# 0                 9.80                 3.00                  NaN
# 1                 9.70                 3.00                  NaN
# 2                 7.80                 3.00                early
# 3                 6.80                 3.00                  NaN
# 4                 1.20                 3.00                  NaN
# (6773, 26)

# %%
# Drop NaN for latter flight data
if True:
    flight_data.dropna(subset=['FORMER_FLIGHT_STATUS'], inplace=True)

# %%
X = flight_data.drop(columns=['ARR_DELAY'])
y = flight_data['ARR_DELAY']

# %%
potential_categorical_vars = {}
# For categorical variables if we are considering variables which were coded to integers, but are actually catagorical.
if True:
    for col in flight_data.columns:
        unique_col_vals = flight_data[col].unique()
        if(len(unique_col_vals) < 15):
            potential_categorical_vars[col] = unique_col_vals
potential_categorical_vars
# Out:
# {'DAY_OF_WEEK': array([6, 7, 1, 2, 3, 4, 5]),
#  'MKT_UNIQUE_CARRIER': array(['B6', 'UA', 'DL', 'AA', 'WN'], dtype=object),
#  'OP_UNIQUE_CARRIER': array(['B6', 'OO', '9E', 'MQ', 'G7', 'PT', 'YX', 'UA', 'WN', 'ZW'],
#        dtype=object),
#  'ORIGIN': array(['MCO', 'ORD', 'JFK'], dtype=object),
#  'ORGIN_WTH_precipprob': array([  0, 100]),
#  'ORGIN_WTH_severerisk': array([  3.,  10.,  30.,   5.,  15.,  60., 100.,   8.,  50.,  19.,  25.,
#          75.,  38.]),
#  'DEST_WTH_precipprob': array([  0, 100]),
#  'DEST_WTH_severerisk': array([  3.,  10.,  30.,  60.,   5.,  75., 100.,   8.]),
#  'FORMER_FLIGHT_STATUS': array(['early', 'late', 'on-time'], dtype=object)}

# %%
# Handle Categorical Variables
categorical_vars = ['DAY_OF_WEEK', 'MKT_UNIQUE_CARRIER',
                    'OP_UNIQUE_CARRIER', 'ORIGIN',
                    'ORGIN_WTH_precipprob', 'ORGIN_WTH_severerisk',
                    'DEST_WTH_precipprob', 'DEST_WTH_severerisk',
                    'FORMER_FLIGHT_STATUS', 'MONTH']

# categorical_vars = potential_categorical_vars.keys()

# %%
def preprocess(flight_data: pd.DataFrame):

    # Dealing with date and time
    flight_data['SCH_ARR_TIME'] = pd.to_datetime(flight_data['SCH_ARR_TIME'])
    flight_data['SCH_DEP_TIME'] = pd.to_datetime(flight_data['SCH_DEP_TIME'])

    flight_data['MONTH'] = flight_data['SCH_ARR_TIME'].dt.month
    flight_data['DAY'] = flight_data['SCH_ARR_TIME'].dt.day
    flight_data['DEP_MINUTES'] = flight_data['SCH_DEP_TIME'].dt.hour * 60 + flight_data['SCH_DEP_TIME'].dt.minute
    flight_data['ARR_MINUTES'] = flight_data['SCH_ARR_TIME'].dt.hour * 60 + flight_data['SCH_ARR_TIME'].dt.minute

    flight_data.drop(columns=['SCH_DEP_TIME', 'SCH_ARR_TIME'], inplace=True)

    # Dropping unwanted columns
    cols = [
        'ORGIN_WTH_temp', 'DEST_WTH_temp',
        'DEST_WTH_severerisk', 'ORGIN_WTH_severerisk',
        'DEST_WTH_precipprob', 'ORGIN_WTH_precipprob'
        ]
    flight_data.drop(columns=cols, inplace=True)
    
    cat_col = list(set(flight_data.columns).intersection(categorical_vars))
    flight_data = pd.get_dummies(flight_data, columns = list(cat_col), drop_first = False)

    return flight_data

# %%
X = preprocess(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 35)

X_train.head()
X_test.head()
y_train.head()
y_test.head()
# Out:
#       ORGIN_WTH_precip  ORGIN_WTH_snow  ORGIN_WTH_windspeed  \
# 1460              0.00            0.00                13.90
# 3395              0.00            0.00                 1.60
# 4434              0.00            0.00                16.50
# 5136              0.00            0.00                 8.40
# 5504              0.00            0.00                 9.60
#
#       ORGIN_WTH_winddir  ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  \
# 1460             290.00                 47.30                  9.90
# 3395              27.00                 23.80                  9.90
# 4434             295.00                 90.30                  9.90
# 5136             140.00                 78.40                  9.90
# 5504             252.00                 24.20                  7.80
#
#       DEST_WTH_precip  DEST_WTH_snow  DEST_WTH_windspeed  DEST_WTH_winddir  \
# 1460             0.00           0.00               20.50            280.00
# 3395             0.00           0.00                4.60             70.00
# 4434             0.00           0.00                0.50            355.00
# 5136             0.00           0.00                0.00              1.00
# 5504             0.00           0.00               13.60            140.00
#
#       DEST_WTH_cloudcover  DEST_WTH_visibility  DAY  DEP_MINUTES  ARR_MINUTES  \
# 1460                89.60                 9.90    9          910         1081
# 3395                48.30                 9.90    8          980         1068
# 4434                86.70                 9.90   24          827          996
# 5136                26.90                 9.90   13         1116         1292
# 5504               100.00                 8.80   24          495          667
#
#       FORMER_FLIGHT_STATUS_early  FORMER_FLIGHT_STATUS_late  \
# 1460                        True                      False
# 3395                        True                      False
# 4434                        True                      False
# 5136                       False                       True
# 5504                       False                       True
#
#       FORMER_FLIGHT_STATUS_on-time  OP_UNIQUE_CARRIER_9E  \
# 1460                         False                 False
# 3395                         False                  True
# 4434                         False                 False
# 5136                         False                 False
# 5504                         False                 False
#
#       OP_UNIQUE_CARRIER_B6  OP_UNIQUE_CARRIER_G7  OP_UNIQUE_CARRIER_MQ  \
# 1460                 False                 False                 False
# 3395                 False                 False                 False
# 4434                 False                 False                 False
# 5136                 False                 False                  True
# 5504                 False                 False                  True
#
#       OP_UNIQUE_CARRIER_OO  OP_UNIQUE_CARRIER_PT  OP_UNIQUE_CARRIER_UA  \
# 1460                 False                 False                 False
# 3395                 False                 False                 False
# 4434                 False                 False                 False
# 5136                 False                 False                 False
# 5504                 False                 False                 False
#
#       OP_UNIQUE_CARRIER_WN  OP_UNIQUE_CARRIER_YX  OP_UNIQUE_CARRIER_ZW  \
# 1460                 False                  True                 False
# 3395                 False                 False                 False
# 4434                 False                  True                 False
# 5136                 False                 False                 False
# 5504                 False                 False                 False
#
#       MONTH_1  MONTH_2  MONTH_3  MONTH_4  MONTH_5  MONTH_6  MONTH_7  MONTH_8  \
# 1460    False    False    False    False    False     True    False    False
# 3395     True    False    False    False    False    False    False    False
# 4434    False    False    False     True    False    False    False    False
# 5136    False    False    False    False    False    False     True    False
# 5504    False    False    False    False    False    False    False     True
#
#       MONTH_9  MONTH_10  MONTH_11  MONTH_12  ORIGIN_JFK  ORIGIN_MCO  \
# 1460    False     False     False     False       False       False
# 3395    False     False     False     False        True       False
# 4434    False     False     False     False       False       False
# 5136    False     False     False     False       False       False
# 5504    False     False     False     False       False       False
#
#       ORIGIN_ORD  DAY_OF_WEEK_1  DAY_OF_WEEK_2  DAY_OF_WEEK_3  DAY_OF_WEEK_4  \
# 1460        True          False          False          False           True
# 3395       False          False          False          False          False
# 4434        True           True          False          False          False
# 5136        True          False          False          False           True
# 5504        True          False          False          False           True
#
#       DAY_OF_WEEK_5  DAY_OF_WEEK_6  DAY_OF_WEEK_7  MKT_UNIQUE_CARRIER_AA  \
# 1460          False          False          False                   True
# 3395          False          False           True                  False
# 4434          False          False          False                   True
# 5136          False          False          False                   True
# 5504          False          False          False                   True
#
#       MKT_UNIQUE_CARRIER_B6  MKT_UNIQUE_CARRIER_DL  MKT_UNIQUE_CARRIER_UA  \
# 1460                  False                  False                  False
# 3395                  False                   True                  False
# 4434                  False                  False                  False
# 5136                  False                  False                  False
# 5504                  False                  False                  False
#
#       MKT_UNIQUE_CARRIER_WN
# 1460                  False
# 3395                  False
# 4434                  False
# 5136                  False
# 5504                  False
#       ORGIN_WTH_precip  ORGIN_WTH_snow  ORGIN_WTH_windspeed  \
# 158               0.00            0.08                 9.20
# 1891              0.00            0.00                 6.90
# 73                0.00            0.00                13.60
# 496               0.00            0.00                 6.00
# 3408              0.00            0.00                 8.70
#
#       ORGIN_WTH_winddir  ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  \
# 158              315.00                100.00                  2.60
# 1891             353.00                 76.30                  9.90
# 73               304.00                  0.00                  9.90
# 496              292.00                  0.80                  9.90
# 3408             191.00                 88.10                  9.90
#
#       DEST_WTH_precip  DEST_WTH_snow  DEST_WTH_windspeed  DEST_WTH_winddir  \
# 158              0.00           0.00                9.30            280.00
# 1891             0.00           0.00               12.70            319.00
# 73               0.00           0.04               19.70            240.00
# 496              0.00           0.05                0.20            354.00
# 3408             0.00           0.00               15.80            251.00
#
#       DEST_WTH_cloudcover  DEST_WTH_visibility  DAY  DEP_MINUTES  ARR_MINUTES  \
# 158                 88.80                 9.80   20          750          825
# 1891                48.80                 9.90   12          835         1010
# 73                  28.70                 9.60   10          760          931
# 496                 50.60                 9.90    2          750          825
# 3408               100.00                 5.00    9         1104         1277
#
#       FORMER_FLIGHT_STATUS_early  FORMER_FLIGHT_STATUS_late  \
# 158                        False                      False
# 1891                        True                      False
# 73                         False                       True
# 496                        False                      False
# 3408                       False                       True
#
#       FORMER_FLIGHT_STATUS_on-time  OP_UNIQUE_CARRIER_9E  \
# 158                           True                  True
# 1891                         False                 False
# 73                           False                 False
# 496                           True                  True
# 3408                         False                 False
#
#       OP_UNIQUE_CARRIER_B6  OP_UNIQUE_CARRIER_G7  OP_UNIQUE_CARRIER_MQ  \
# 158                  False                 False                 False
# 1891                 False                 False                 False
# 73                   False                 False                 False
# 496                  False                 False                 False
# 3408                 False                 False                 False
#
#       OP_UNIQUE_CARRIER_OO  OP_UNIQUE_CARRIER_PT  OP_UNIQUE_CARRIER_UA  \
# 158                  False                 False                 False
# 1891                 False                 False                  True
# 73                    True                 False                 False
# 496                  False                 False                 False
# 3408                 False                 False                  True
#
#       OP_UNIQUE_CARRIER_WN  OP_UNIQUE_CARRIER_YX  OP_UNIQUE_CARRIER_ZW  \
# 158                  False                 False                 False
# 1891                 False                 False                 False
# 73                   False                 False                 False
# 496                  False                 False                 False
# 3408                 False                 False                 False
#
#       MONTH_1  MONTH_2  MONTH_3  MONTH_4  MONTH_5  MONTH_6  MONTH_7  MONTH_8  \
# 158      True    False    False    False    False    False    False    False
# 1891    False    False    False    False    False    False    False     True
# 73       True    False    False    False    False    False    False    False
# 496     False    False     True    False    False    False    False    False
# 3408     True    False    False    False    False    False    False    False
#
#       MONTH_9  MONTH_10  MONTH_11  MONTH_12  ORIGIN_JFK  ORIGIN_MCO  \
# 158     False     False     False     False        True       False
# 1891    False     False     False     False       False       False
# 73      False     False     False     False       False       False
# 496     False     False     False     False        True       False
# 3408    False     False     False     False       False       False
#
#       ORIGIN_ORD  DAY_OF_WEEK_1  DAY_OF_WEEK_2  DAY_OF_WEEK_3  DAY_OF_WEEK_4  \
# 158        False          False          False          False           True
# 1891        True          False          False          False          False
# 73          True           True          False          False          False
# 496        False          False          False           True          False
# 3408        True           True          False          False          False
#
#       DAY_OF_WEEK_5  DAY_OF_WEEK_6  DAY_OF_WEEK_7  MKT_UNIQUE_CARRIER_AA  \
# 158           False          False          False                  False
# 1891           True          False          False                  False
# 73            False          False          False                   True
# 496           False          False          False                  False
# 3408          False          False          False                  False
#
#       MKT_UNIQUE_CARRIER_B6  MKT_UNIQUE_CARRIER_DL  MKT_UNIQUE_CARRIER_UA  \
# 158                   False                   True                  False
# 1891                  False                  False                   True
# 73                    False                  False                  False
# 496                   False                   True                  False
# 3408                  False                  False                   True
#
#       MKT_UNIQUE_CARRIER_WN
# 158                   False
# 1891                  False
# 73                    False
# 496                   False
# 3408                  False
# 1460   -17.00
# 3395    -9.00
# 4434    -1.00
# 5136    17.00
# 5504    20.00
# Name: ARR_DELAY, dtype: float64
# 158      9.00
# 1891   -11.00
# 73     -13.00
# 496    -14.00
# 3408   -16.00
# Name: ARR_DELAY, dtype: float64

# %%
def sMAPE_metric(actual_values, predicted_values):
    actual_predicted_absolute_sum = np.abs(actual_values) + np.abs(predicted_values)
    actual_predicted_absolute_diff = np.abs(actual_values - predicted_values)
    sMAPE = np.mean(actual_predicted_absolute_diff / actual_predicted_absolute_sum)
    return sMAPE

# %%
gb = GradientBoostingRegressor(random_state=50, min_samples_leaf = 2, min_samples_split = 6, max_depth = 5)

gb = gb.fit(X_train, y_train) 
test_output_gb = pd.DataFrame(gb.predict(X_test), index = X_test.index, columns = ['pred_ARR_DELAY'])
test_output_gb = test_output_gb.merge(y_test, left_index = True, right_index = True)
test_output_gb.head()
mean_absolute_error_gb = abs(test_output_gb['pred_ARR_DELAY'] - test_output_gb['ARR_DELAY']).mean()
print(f"GradientBoostingRegressor mean absolute error is: {mean_absolute_error_gb:.2f}")
print(f"GradientBoostingRegressor error ratio: {abs(test_output_gb['pred_ARR_DELAY'] - test_output_gb['ARR_DELAY']).mean()/test_output_gb['ARR_DELAY'].mean():.2f}")
test_output_gb['ARR_DELAY'].mean()
# Out:
#       pred_ARR_DELAY  ARR_DELAY
# 158            25.05       9.00
# 1891            2.49     -11.00
# 73              4.28     -13.00
# 496            11.30     -14.00
# 3408            8.11     -16.00
# GradientBoostingRegressor mean absolute error is: 24.16
# GradientBoostingRegressor error ratio: 3.24
# 7.450897571277719

# %%
print(f"sMAPE for GradientBoostingRegressor model: {sMAPE_metric(test_output_gb['pred_ARR_DELAY'], test_output_gb['ARR_DELAY']) * 100:.2f}")
# Out:
# sMAPE for GradientBoostingRegressor model: 72.28

# %% [markdown]
# ## Trying classification

# %%
def categorize_delay(delay):
    if delay < -7:
        return 0 #early
    elif delay > 6:
        return 2 #late
    else:
        return 1 #ontime

# %%
y = flight_data['ARR_DELAY'].apply(categorize_delay)
y.value_counts()
# Out:
# ARR_DELAY
# 0    1957
# 2    1437
# 1    1338
# Name: count, dtype: int64

# %% [markdown]
# ##### Trying SMOT

# %%
import imblearn
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

if False:
    over = SMOTE()
    under = RandomUnderSampler()
    steps = [('o', over), ('u', under)]
    pipeline = Pipeline(steps=steps)

    x_smote, y_smote = pipeline.fit_resample(X, y)

    counter = Counter(y)
    for k,v in counter.items():
        per = v / len(y) * 100

    plt.bar(counter.keys(), counter.values())
    plt.xlabel("Class value distribution before sampling")
    plt.show()

    counter = Counter(y_smote)
    for k,v in counter.items():
        per = v / len(y) * 100

    plt.bar(counter.keys(), counter.values())
    plt.xlabel("Class value distribution before sampling")
    plt.show()

    X_train, X_test, y_train, y_test = train_test_split(x_smote, y_smote, stratify=y_smote, test_size=0.20, random_state = 21)
else:
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state = 21)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'min_child_weight': [1, 2, 3],
    'learning_rate': [0.1, 0.01, 0.005],
    'max_depth': [1, 2, 3, 4]
}

xgb_classifier = XGBClassifier(
    n_estimators=600,
    reg_lambda=0.007
)

grid_search = GridSearchCV(
    estimator=xgb_classifier,
    param_grid=param_grid,
    scoring='accuracy',  # Consider other metrics such as 'f1_macro' for imbalanced classes
    cv=7,
    verbose=1
)


grid_search.fit(X, y)


print("Best parameters for the XGBClassifier model:", grid_search.best_params_)
best_score = grid_search.best_score_ * 100
print(f"Best Accuracy: {best_score:.4f}%")


for i in range(len(grid_search.cv_results_['mean_test_score'])):
    params = grid_search.cv_results_['params'][i]
    mean_test_score = grid_search.cv_results_['mean_test_score'][i]
    std_deviation_score = grid_search.cv_results_['std_test_score'][i]
    print(f"Parameters selected: {params}, Mean Accuracy: {mean_test_score*100:.4f}%, Standard Deviation: {std_deviation_score*100:.4f}%")
# Out:
# Fitting 7 folds for each of 36 candidates, totalling 252 fits
# GridSearchCV(cv=7,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=600,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.01, 0.005],
#                          'max_depth': [1, 2, 3, 4],
#                          'min_child_weight': [1, 2, 3]},
#              scoring='accuracy', verbose=1)
# Best parameters for the XGBClassifier model: {'learning_rate': 0.01, 'max_depth': 1, 'min_child_weight': 2}
# Best Accuracy: 43.4911%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 1, 'min_child_weight': 1}, Mean Accuracy: 38.5883%, Standard Deviation: 4.7820%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 1, 'min_child_weight': 2}, Mean Accuracy: 39.4336%, Standard Deviation: 4.1944%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 1, 'min_child_weight': 3}, Mean Accuracy: 39.3491%, Standard Deviation: 4.0674%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 1}, Mean Accuracy: 36.4751%, Standard Deviation: 4.8103%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 2}, Mean Accuracy: 36.7075%, Standard Deviation: 4.5143%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 3}, Mean Accuracy: 36.9822%, Standard Deviation: 3.8217%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1}, Mean Accuracy: 36.5173%, Standard Deviation: 5.2720%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2}, Mean Accuracy: 35.8199%, Standard Deviation: 4.7287%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3}, Mean Accuracy: 35.9890%, Standard Deviation: 4.4630%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1}, Mean Accuracy: 35.0380%, Standard Deviation: 5.6460%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2}, Mean Accuracy: 35.3973%, Standard Deviation: 5.3247%
# Parameters selected: {'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3}, Mean Accuracy: 35.4184%, Standard Deviation: 4.0811%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 1, 'min_child_weight': 1}, Mean Accuracy: 43.0896%, Standard Deviation: 2.1183%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 1, 'min_child_weight': 2}, Mean Accuracy: 43.4911%, Standard Deviation: 1.8118%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 1, 'min_child_weight': 3}, Mean Accuracy: 43.4911%, Standard Deviation: 1.8118%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 1}, Mean Accuracy: 40.5325%, Standard Deviation: 3.3444%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2}, Mean Accuracy: 40.8707%, Standard Deviation: 2.8539%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 3}, Mean Accuracy: 40.7861%, Standard Deviation: 2.7354%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1}, Mean Accuracy: 39.8563%, Standard Deviation: 3.9928%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 2}, Mean Accuracy: 40.1310%, Standard Deviation: 3.3795%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3}, Mean Accuracy: 40.0888%, Standard Deviation: 3.3991%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 1}, Mean Accuracy: 39.5182%, Standard Deviation: 4.7095%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 2}, Mean Accuracy: 39.3491%, Standard Deviation: 4.2012%
# Parameters selected: {'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 3}, Mean Accuracy: 39.6872%, Standard Deviation: 4.2210%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 1, 'min_child_weight': 1}, Mean Accuracy: 43.3855%, Standard Deviation: 2.2790%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 1, 'min_child_weight': 2}, Mean Accuracy: 43.3855%, Standard Deviation: 2.2790%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 1, 'min_child_weight': 3}, Mean Accuracy: 43.3855%, Standard Deviation: 2.2790%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 2, 'min_child_weight': 1}, Mean Accuracy: 42.0541%, Standard Deviation: 2.7615%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 2, 'min_child_weight': 2}, Mean Accuracy: 42.1175%, Standard Deviation: 2.6198%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 2, 'min_child_weight': 3}, Mean Accuracy: 42.0752%, Standard Deviation: 2.6696%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 3, 'min_child_weight': 1}, Mean Accuracy: 41.2933%, Standard Deviation: 3.7519%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 3, 'min_child_weight': 2}, Mean Accuracy: 41.2933%, Standard Deviation: 3.4579%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 3, 'min_child_weight': 3}, Mean Accuracy: 41.5258%, Standard Deviation: 3.4273%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 4, 'min_child_weight': 1}, Mean Accuracy: 40.7227%, Standard Deviation: 3.8394%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 4, 'min_child_weight': 2}, Mean Accuracy: 40.4691%, Standard Deviation: 3.6078%
# Parameters selected: {'learning_rate': 0.005, 'max_depth': 4, 'min_child_weight': 3}, Mean Accuracy: 40.4269%, Standard Deviation: 3.9636%

# %%
def lineplot(learning_rate_range, train, test, title):
    plt.plot(learning_rate_range, test, c='m', label='Test')
    plt.plot(learning_rate_range, train, c='orange', label='Train')
    plt.xlabel('Learning rate')
    plt.xticks(learning_rate_range)
    plt.ylabel('Accuracy score')
    plt.ylim(0.5, 1)
    plt.legend(prop={'size': 12}, loc=3)
    plt.title(title, size=14)

# %% [markdown]
# #### xgBoost

# %%
if False:
    # XGBoost (different learning rate)
    learning_rate_range = np.arange(0.01, 1, 0.05)
    test = [] 
    train = []
    for lr in learning_rate_range:
        xgb_classifier = xgb.XGBClassifier(eta = lr)
        _ =xgb_classifier.fit(X_train, y_train)
        train.append(xgb_classifier.score(X_train, y_train))
        test.append(xgb_classifier.score(X_test, y_test))
    # Line plot
    fig = plt.figure(figsize=(10, 7))
    lineplot(learning_rate_range, train, test, title='Accuracy score vs. Learning rate of XGBoost')
    plt.show()

    # Resolve overfitting 
    # new learning rate range
    learning_rate_range = np.arange(0.01, 0.5, 0.05)
    fig = plt.figure(figsize=(19, 17))
    idx = 1
    # grid search for min_child_weight
    for weight in np.arange(0, 4.5, 0.5):
        train = []
        test = []
        for lr in learning_rate_range:
            xgb_classifier = xgb.XGBClassifier(eta = lr, reg_lambda=1, min_child_weight=weight)
            _ = xgb_classifier.fit(X_train, y_train)
            train.append(xgb_classifier.score(X_train, y_train))
            test.append(xgb_classifier.score(X_test, y_test))
        fig.add_subplot(3, 3, idx)
        idx += 1
        title = "Min child weight:" + str(weight)
        lineplot(learning_rate_range, train ,test, title)
    plt.show()

# %%
xg_model = xgb.XGBClassifier(eta = '0.08', max_depth=5, min_child_weight=1, reg_lambda=0.007)
xg_model = xg_model.fit(X_train, y_train) 
xg_model.score(X_train, y_train) 

# gb.feature_importances_
feat_imp = pd.Series(xg_model.feature_importances_, X_train.columns.values).sort_values(ascending=False)

feat_imp_table = pd.DataFrame(feat_imp)
feat_imp_table = feat_imp_table.reset_index()
feat_imp_table.columns = ['Features', 'Values']
feat_imp.head(20)

test_output = pd.DataFrame(xg_model.predict(X_test), index = X_test.index, columns = ['pred_Y'])
test_output = test_output.merge(y_test, left_index = True, right_index = True)
test_output.head()
print('Fraction of correct classification ')
xg_model.score(X_test, y_test) 
test_output['pred_Y'].value_counts()
# Out:
# 0.7101717305151916
# MKT_UNIQUE_CARRIER_DL        0.07
# OP_UNIQUE_CARRIER_B6         0.05
# ORGIN_WTH_snow               0.03
# OP_UNIQUE_CARRIER_UA         0.03
# OP_UNIQUE_CARRIER_MQ         0.03
# OP_UNIQUE_CARRIER_OO         0.03
# MONTH_5                      0.03
# FORMER_FLIGHT_STATUS_early   0.02
# MONTH_1                      0.02
# ORIGIN_ORD                   0.02
# ARR_MINUTES                  0.02
# MKT_UNIQUE_CARRIER_AA        0.02
# ORGIN_WTH_visibility         0.02
# MONTH_8                      0.02
# MONTH_11                     0.02
# DAY_OF_WEEK_3                0.02
# MONTH_7                      0.02
# ORGIN_WTH_precip             0.02
# OP_UNIQUE_CARRIER_WN         0.02
# DEP_MINUTES                  0.02
# dtype: float32
#       pred_Y  ARR_DELAY
# 2237       0          0
# 2429       0          2
# 2706       1          2
# 2526       0          1
# 2438       0          2
# Fraction of correct classification
# 0.4941921858500528
# pred_Y
# 0    579
# 2    226
# 1    142
# Name: count, dtype: int64

# %% [markdown]
# #### GradientBoosting

# %%
gb = GradientBoostingClassifier(random_state=50, min_samples_split = 2, min_samples_leaf = 6, max_depth = 7, n_estimators = 200)
gb = gb.fit(X_train, y_train) 
gb.score(X_train, y_train) 

# gb.feature_importances_
feat_imp = pd.Series(gb.feature_importances_, X_train.columns.values).sort_values(ascending=False)

feat_imp_table = pd.DataFrame(feat_imp)
feat_imp_table = feat_imp_table.reset_index()
feat_imp_table.columns = ['Features', 'Values']
feat_imp.head(20)

test_output = pd.DataFrame(gb.predict(X_test), index = X_test.index, columns = ['pred_Y'])
test_output = test_output.merge(y_test, left_index = True, right_index = True)
test_output.head()
print('Fraction of correct classification ')
gb.score(X_test, y_test) 
test_output['pred_Y'].value_counts()
# Out:
# 0.9994715984147953
# ORGIN_WTH_winddir            0.10
# ORGIN_WTH_windspeed          0.10
# DEST_WTH_winddir             0.09
# DEST_WTH_windspeed           0.09
# ARR_MINUTES                  0.07
# DAY                          0.07
# DEP_MINUTES                  0.07
# ORGIN_WTH_cloudcover         0.07
# DEST_WTH_cloudcover          0.06
# DEST_WTH_visibility          0.03
# ORGIN_WTH_visibility         0.02
# DEST_WTH_precip              0.02
# ORGIN_WTH_precip             0.01
# FORMER_FLIGHT_STATUS_early   0.01
# MKT_UNIQUE_CARRIER_DL        0.01
# OP_UNIQUE_CARRIER_UA         0.01
# OP_UNIQUE_CARRIER_B6         0.01
# DAY_OF_WEEK_1                0.01
# DAY_OF_WEEK_5                0.01
# ORGIN_WTH_snow               0.01
# dtype: float64
#       pred_Y  ARR_DELAY
# 2237       1          0
# 2429       0          2
# 2706       2          2
# 2526       0          1
# 2438       0          2
# Fraction of correct classification
# 0.4699049630411827
# pred_Y
# 0    487
# 2    278
# 1    182
# Name: count, dtype: int64

# %% [markdown]
# ##### Random Forest

# %%
rf = RandomForestClassifier(max_features='sqrt', min_samples_leaf=4)
rf = rf.fit(X_train, y_train)
rf.score(X_train, y_train)

feat_imp = pd.Series(rf.feature_importances_, X_train.columns.values).sort_values(ascending=False)
feat_imp.head(20)

test_output = pd.DataFrame(rf.predict(X_test), index = X_test.index, columns = ['pred_Y'])

test_output.head()
test_output = test_output.merge(y_test, left_index = True, right_index = True)
test_output.head()
print('Fraction of correct classification ')
rf.score(X_test, y_test) 
test_output['pred_Y'].value_counts()
# Out:
# 0.8826948480845442
# ORGIN_WTH_windspeed            0.08
# DEST_WTH_winddir               0.08
# ORGIN_WTH_winddir              0.08
# ARR_MINUTES                    0.08
# DEP_MINUTES                    0.07
# DEST_WTH_windspeed             0.07
# ORGIN_WTH_cloudcover           0.07
# DAY                            0.07
# DEST_WTH_cloudcover            0.06
# DEST_WTH_visibility            0.03
# ORGIN_WTH_visibility           0.03
# FORMER_FLIGHT_STATUS_early     0.02
# DEST_WTH_precip                0.01
# ORGIN_WTH_precip               0.01
# OP_UNIQUE_CARRIER_B6           0.01
# MKT_UNIQUE_CARRIER_DL          0.01
# FORMER_FLIGHT_STATUS_late      0.01
# MKT_UNIQUE_CARRIER_B6          0.01
# FORMER_FLIGHT_STATUS_on-time   0.01
# DAY_OF_WEEK_1                  0.01
# dtype: float64
#       pred_Y
# 2237       0
# 2429       0
# 2706       0
# 2526       0
# 2438       0
#       pred_Y  ARR_DELAY
# 2237       0          0
# 2429       0          2
# 2706       0          2
# 2526       0          1
# 2438       0          2
# Fraction of correct classification
# 0.5068637803590285
# pred_Y
# 0    581
# 2    256
# 1    110
# Name: count, dtype: int64
