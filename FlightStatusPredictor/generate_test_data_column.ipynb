# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %% [markdown]
# ## Predictions for April 9th, 2024:

# %%
initial_predictions_dataset = pd.read_csv("./test_data/Professor_CSV.csv")

# %%
initial_predictions_dataset.head(10)
# Out:
#       DATE        DAY FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER  \
# 0  4/10/24  WEDNESDAY       UA 1400                 UA                UA
# 1  4/10/24  WEDNESDAY       AA 3402                 AA                MQ
# 2  4/10/24  WEDNESDAY        B6 116                 B6                B6
# 3  4/10/24  WEDNESDAY       DL 5182                 DL                9E
# 4  4/10/24  WEDNESDAY       WN 5285                 WN                WN
# 5  4/10/24  WEDNESDAY        B6 656                 B6                B6
# 6  4/11/24   THURSDAY       UA 1400                 UA                UA
# 7  4/11/24   THURSDAY       AA 3402                 AA                MQ
# 8  4/11/24   THURSDAY        B6 116                 B6                B6
# 9  4/11/24   THURSDAY       DL 5182                 DL                9E
#
#   ORIGIN DEPARTURE TIME ARRIVAL TIME  ARRIVAL STATUS  \
# 0    ORD        6:52 PM      9:47 PM             NaN
# 1    ORD        7:59 PM     10:52 PM             NaN
# 2    JFK        1:33 PM      2:50 PM             NaN
# 3    JFK        2:55 PM      4:21 PM             NaN
# 4    MCO       11:05 AM      1:45 PM             NaN
# 5    MCO        1:35 PM      4:25 PM             NaN
# 6    ORD        6:52 PM      9:47 PM             NaN
# 7    ORD        7:59 PM     10:52 PM             NaN
# 8    JFK        1:33 PM      2:50 PM             NaN
# 9    JFK        2:55 PM      4:21 PM             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# 5                               NaN                                NaN
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN

# %%
initial_predictions_dataset.columns
# Out:
# Index(['DATE', 'DAY', 'FLIGHT NUMBER', 'MKT_UNIQUE_CARRIER',
#        'OP_UNIQUE_CARRIER', 'ORIGIN', 'DEPARTURE TIME', 'ARRIVAL TIME',
#        'ARRIVAL STATUS', 'ARRIVAL STATUS_Prev_flight_early',
#        'ARRIVAL STATUS_Prev_flight_ontime', 'ARRIVAL STATUS_Prev_flight_late'],
#       dtype='object')

# %%
initial_predictions_dataset.dtypes
# Out:
# DATE                                  object
# DAY                                   object
# FLIGHT NUMBER                         object
# MKT_UNIQUE_CARRIER                    object
# OP_UNIQUE_CARRIER                     object
# ORIGIN                                object
# DEPARTURE TIME                        object
# ARRIVAL TIME                          object
# ARRIVAL STATUS                       float64
# ARRIVAL STATUS_Prev_flight_early     float64
# ARRIVAL STATUS_Prev_flight_ontime    float64
# ARRIVAL STATUS_Prev_flight_late      float64
# dtype: object

# %%
def convert_to_24hr_format(date, time):
    # Adjust the format to match the 'month/day/year' structure
    return pd.to_datetime(date + ' ' + time, format='%m/%d/%y %I:%M %p')

initial_predictions_dataset['SCH_DEP_TIME'] = initial_predictions_dataset.apply(
    lambda row: convert_to_24hr_format(row['DATE'], row['DEPARTURE TIME']), axis=1)
initial_predictions_dataset['SCH_ARR_TIME'] = initial_predictions_dataset.apply(
    lambda row: convert_to_24hr_format(row['DATE'], row['ARRIVAL TIME']), axis=1)

initial_predictions_dataset.head(10)
# Out:
#       DATE        DAY FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER  \
# 0  4/10/24  WEDNESDAY       UA 1400                 UA                UA
# 1  4/10/24  WEDNESDAY       AA 3402                 AA                MQ
# 2  4/10/24  WEDNESDAY        B6 116                 B6                B6
# 3  4/10/24  WEDNESDAY       DL 5182                 DL                9E
# 4  4/10/24  WEDNESDAY       WN 5285                 WN                WN
# 5  4/10/24  WEDNESDAY        B6 656                 B6                B6
# 6  4/11/24   THURSDAY       UA 1400                 UA                UA
# 7  4/11/24   THURSDAY       AA 3402                 AA                MQ
# 8  4/11/24   THURSDAY        B6 116                 B6                B6
# 9  4/11/24   THURSDAY       DL 5182                 DL                9E
#
#   ORIGIN DEPARTURE TIME ARRIVAL TIME  ARRIVAL STATUS  \
# 0    ORD        6:52 PM      9:47 PM             NaN
# 1    ORD        7:59 PM     10:52 PM             NaN
# 2    JFK        1:33 PM      2:50 PM             NaN
# 3    JFK        2:55 PM      4:21 PM             NaN
# 4    MCO       11:05 AM      1:45 PM             NaN
# 5    MCO        1:35 PM      4:25 PM             NaN
# 6    ORD        6:52 PM      9:47 PM             NaN
# 7    ORD        7:59 PM     10:52 PM             NaN
# 8    JFK        1:33 PM      2:50 PM             NaN
# 9    JFK        2:55 PM      4:21 PM             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# 5                               NaN                                NaN
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late        SCH_DEP_TIME        SCH_ARR_TIME
# 0                              NaN 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1                              NaN 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2                              NaN 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3                              NaN 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4                              NaN 2024-04-10 11:05:00 2024-04-10 13:45:00
# 5                              NaN 2024-04-10 13:35:00 2024-04-10 16:25:00
# 6                              NaN 2024-04-11 18:52:00 2024-04-11 21:47:00
# 7                              NaN 2024-04-11 19:59:00 2024-04-11 22:52:00
# 8                              NaN 2024-04-11 13:33:00 2024-04-11 14:50:00
# 9                              NaN 2024-04-11 14:55:00 2024-04-11 16:21:00

# %%
initial_predictions_dataset.drop(columns=['DATE', 'DEPARTURE TIME', 'ARRIVAL TIME'], inplace = True) 
initial_predictions_dataset.head()
# Out:
#          DAY FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  \
# 0  WEDNESDAY       UA 1400                 UA                UA    ORD
# 1  WEDNESDAY       AA 3402                 AA                MQ    ORD
# 2  WEDNESDAY        B6 116                 B6                B6    JFK
# 3  WEDNESDAY       DL 5182                 DL                9E    JFK
# 4  WEDNESDAY       WN 5285                 WN                WN    MCO
#
#    ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0             NaN                               NaN
# 1             NaN                               NaN
# 2             NaN                               NaN
# 3             NaN                               NaN
# 4             NaN                               NaN
#
#    ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#          SCH_DEP_TIME        SCH_ARR_TIME
# 0 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4 2024-04-10 11:05:00 2024-04-10 13:45:00

# %%
# Define a mapping from day names to numbers
day_to_number = {
    'MONDAY': 1,
    'TUESDAY': 2,
    'WEDNESDAY': 3,
    'THURSDAY': 4,
    'FRIDAY': 5,
    'SATURDAY': 6,
    'SUNDAY': 7
}

# Apply the mapping to the 'DAY' column to create 'DAY_OF_WEEK'
initial_predictions_dataset['DAY_OF_WEEK'] = initial_predictions_dataset['DAY'].map(day_to_number)
initial_predictions_dataset.drop(columns=['DAY'], inplace=True)
# Verify the changes
initial_predictions_dataset.head()
# Out:
#   FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  ARRIVAL STATUS  \
# 0       UA 1400                 UA                UA    ORD             NaN
# 1       AA 3402                 AA                MQ    ORD             NaN
# 2        B6 116                 B6                B6    JFK             NaN
# 3       DL 5182                 DL                9E    JFK             NaN
# 4       WN 5285                 WN                WN    MCO             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late        SCH_DEP_TIME        SCH_ARR_TIME  \
# 0                              NaN 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1                              NaN 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2                              NaN 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3                              NaN 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4                              NaN 2024-04-10 11:05:00 2024-04-10 13:45:00
#
#    DAY_OF_WEEK
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3

# %%
# Negative "diff_arrival_departure" indicates that flight arrive next day.
diff_arrival_departure = initial_predictions_dataset['SCH_ARR_TIME'] - initial_predictions_dataset['SCH_DEP_TIME']


initial_predictions_dataset = initial_predictions_dataset[diff_arrival_departure > pd.Timedelta(0)]

initial_predictions_dataset.shape
initial_predictions_dataset.dtypes
# Out:
# (51, 11)
# FLIGHT NUMBER                                object
# MKT_UNIQUE_CARRIER                           object
# OP_UNIQUE_CARRIER                            object
# ORIGIN                                       object
# ARRIVAL STATUS                              float64
# ARRIVAL STATUS_Prev_flight_early            float64
# ARRIVAL STATUS_Prev_flight_ontime           float64
# ARRIVAL STATUS_Prev_flight_late             float64
# SCH_DEP_TIME                         datetime64[ns]
# SCH_ARR_TIME                         datetime64[ns]
# DAY_OF_WEEK                                   int64
# dtype: object

# %%
initial_predictions_dataset['DEST'] = 'SYR'

# %%
weather_data = pd.read_csv('./test_data/Test_Weather_Data.csv', parse_dates=['datetime'])
weather_data.head()
weather_data.shape
weather_data.dtypes
# Out:
#       name            datetime  temp  feelslike   dew  humidity  precip  \
# 0  Chicago 2024-04-08 00:00:00 48.50      45.40 41.40     76.37    0.00
# 1  Chicago 2024-04-08 01:00:00 49.20      46.20 40.20     71.16    0.00
# 2  Chicago 2024-04-08 02:00:00 48.70      46.00 40.90     74.21    0.00
# 3  Chicago 2024-04-08 03:00:00 47.70      44.90 40.90     76.95    0.00
# 4  Chicago 2024-04-08 04:00:00 47.70      43.80 41.80     79.87    0.00
#
#    precipprob preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# 0           0        NaN  0.00       0.00     16.10       6.90      135
# 1           0        NaN  0.00       0.00     13.90       6.90      157
# 2           0        NaN  0.00       0.00     11.40       6.30      161
# 3           0        NaN  0.00       0.00     10.30       6.10      166
# 4           0        NaN  0.00       0.00     15.00       8.40      170
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0          1,010.70        0.00        9.90               0         0.00
# 1          1,010.30        0.00        9.90               0         0.00
# 2          1,010.00        0.00        9.90               0         0.00
# 3          1,009.70        0.00        9.90               0         0.00
# 4          1,009.50        0.00        9.90               0         0.00
#
#    uvindex  severerisk conditions         icon  \
# 0        0          10      Clear  clear-night
# 1        0          10      Clear  clear-night
# 2        0          10      Clear  clear-night
# 3        0          10      Clear  clear-night
# 4        0          10      Clear  clear-night
#
#                                             stations
# 0  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 1  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 2  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 3  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 4  72534014819,KORD,KMDW,72530094846,F1983,744665...
# (1056, 24)
# name                        object
# datetime            datetime64[ns]
# temp                       float64
# feelslike                  float64
# dew                        float64
# humidity                   float64
# precip                     float64
# precipprob                   int64
# preciptype                  object
# snow                       float64
# snowdepth                  float64
# windgust                   float64
# windspeed                  float64
# winddir                      int64
# sealevelpressure           float64
# cloudcover                 float64
# visibility                 float64
# solarradiation               int64
# solarenergy                float64
# uvindex                      int64
# severerisk                   int64
# conditions                  object
# icon                        object
# stations                    object
# dtype: object

# %%
print(set(weather_data['name']))
# Out:
# {'New York', 'Syracuse', 'Chicago', 'Orlando'}

# %%
# Replacing city names with airport names
dic = {'syracuse': 'SYR', 'new york': 'JFK', 'orlando': 'MCO', 'chicago': 'ORD'}

weather_data['name'] = weather_data['name'].apply(lambda row: dic[row.lower()])

weather_data.head()
print(set(weather_data['name']))
# Out:
#   name            datetime  temp  feelslike   dew  humidity  precip  \
# 0  ORD 2024-04-08 00:00:00 48.50      45.40 41.40     76.37    0.00
# 1  ORD 2024-04-08 01:00:00 49.20      46.20 40.20     71.16    0.00
# 2  ORD 2024-04-08 02:00:00 48.70      46.00 40.90     74.21    0.00
# 3  ORD 2024-04-08 03:00:00 47.70      44.90 40.90     76.95    0.00
# 4  ORD 2024-04-08 04:00:00 47.70      43.80 41.80     79.87    0.00
#
#    precipprob preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# 0           0        NaN  0.00       0.00     16.10       6.90      135
# 1           0        NaN  0.00       0.00     13.90       6.90      157
# 2           0        NaN  0.00       0.00     11.40       6.30      161
# 3           0        NaN  0.00       0.00     10.30       6.10      166
# 4           0        NaN  0.00       0.00     15.00       8.40      170
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0          1,010.70        0.00        9.90               0         0.00
# 1          1,010.30        0.00        9.90               0         0.00
# 2          1,010.00        0.00        9.90               0         0.00
# 3          1,009.70        0.00        9.90               0         0.00
# 4          1,009.50        0.00        9.90               0         0.00
#
#    uvindex  severerisk conditions         icon  \
# 0        0          10      Clear  clear-night
# 1        0          10      Clear  clear-night
# 2        0          10      Clear  clear-night
# 3        0          10      Clear  clear-night
# 4        0          10      Clear  clear-night
#
#                                             stations
# 0  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 1  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 2  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 3  72534014819,KORD,KMDW,72530094846,F1983,744665...
# 4  72534014819,KORD,KMDW,72530094846,F1983,744665...
# {'SYR', 'MCO', 'JFK', 'ORD'}

# %%
weather_columns_to_drop = ['dew','humidity','snowdepth','sealevelpressure', 'solarradiation', 'solarenergy','uvindex','icon','stations']
weather_data.drop(columns = weather_columns_to_drop, inplace=True)

# %%
# Create two data frame for origin and destination. Also rename the columns by adding the prefix.
rename_origin = {}
rename_dest = {}
for col in weather_data.columns:
    rename_origin[col] = 'ORGIN_WTH_' + col
    rename_dest[col] = 'DEST_WTH_' + col
    
org_weather_data = weather_data.rename(columns=rename_origin)
dst_weather_data = weather_data.rename(columns=rename_dest)

# %%
# Adding Join columns
initial_predictions_dataset['ORGIN_WTH_JOIN'] = initial_predictions_dataset['SCH_DEP_TIME'].dt.round('H').astype(str) + initial_predictions_dataset['ORIGIN']
initial_predictions_dataset['DEST_WTH_JOIN'] = initial_predictions_dataset['SCH_ARR_TIME'].dt.round('H').astype(str) + initial_predictions_dataset['DEST']
org_weather_data['ORGIN_WTH_JOIN'] = org_weather_data['ORGIN_WTH_datetime'].astype(str) + org_weather_data['ORGIN_WTH_name']
dst_weather_data['DEST_WTH_JOIN'] = dst_weather_data['DEST_WTH_datetime'].astype(str) + dst_weather_data['DEST_WTH_name']
initial_predictions_dataset.head()
org_weather_data.head()
dst_weather_data.head()
# Out:
#   FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  ARRIVAL STATUS  \
# 0       UA 1400                 UA                UA    ORD             NaN
# 1       AA 3402                 AA                MQ    ORD             NaN
# 2        B6 116                 B6                B6    JFK             NaN
# 3       DL 5182                 DL                9E    JFK             NaN
# 4       WN 5285                 WN                WN    MCO             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late        SCH_DEP_TIME        SCH_ARR_TIME  \
# 0                              NaN 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1                              NaN 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2                              NaN 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3                              NaN 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4                              NaN 2024-04-10 11:05:00 2024-04-10 13:45:00
#
#    DAY_OF_WEEK DEST          ORGIN_WTH_JOIN           DEST_WTH_JOIN
# 0            3  SYR  2024-04-10 19:00:00ORD  2024-04-10 22:00:00SYR
# 1            3  SYR  2024-04-10 20:00:00ORD  2024-04-10 23:00:00SYR
# 2            3  SYR  2024-04-10 14:00:00JFK  2024-04-10 15:00:00SYR
# 3            3  SYR  2024-04-10 15:00:00JFK  2024-04-10 16:00:00SYR
# 4            3  SYR  2024-04-10 11:00:00MCO  2024-04-10 14:00:00SYR
#   ORGIN_WTH_name  ORGIN_WTH_datetime  ORGIN_WTH_temp  ORGIN_WTH_feelslike  \
# 0            ORD 2024-04-08 00:00:00           48.50                45.40
# 1            ORD 2024-04-08 01:00:00           49.20                46.20
# 2            ORD 2024-04-08 02:00:00           48.70                46.00
# 3            ORD 2024-04-08 03:00:00           47.70                44.90
# 4            ORD 2024-04-08 04:00:00           47.70                43.80
#
#    ORGIN_WTH_precip  ORGIN_WTH_precipprob ORGIN_WTH_preciptype  \
# 0              0.00                     0                  NaN
# 1              0.00                     0                  NaN
# 2              0.00                     0                  NaN
# 3              0.00                     0                  NaN
# 4              0.00                     0                  NaN
#
#    ORGIN_WTH_snow  ORGIN_WTH_windgust  ORGIN_WTH_windspeed  ORGIN_WTH_winddir  \
# 0            0.00               16.10                 6.90                135
# 1            0.00               13.90                 6.90                157
# 2            0.00               11.40                 6.30                161
# 3            0.00               10.30                 6.10                166
# 4            0.00               15.00                 8.40                170
#
#    ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  ORGIN_WTH_severerisk  \
# 0                  0.00                  9.90                    10
# 1                  0.00                  9.90                    10
# 2                  0.00                  9.90                    10
# 3                  0.00                  9.90                    10
# 4                  0.00                  9.90                    10
#
#   ORGIN_WTH_conditions          ORGIN_WTH_JOIN
# 0                Clear  2024-04-08 00:00:00ORD
# 1                Clear  2024-04-08 01:00:00ORD
# 2                Clear  2024-04-08 02:00:00ORD
# 3                Clear  2024-04-08 03:00:00ORD
# 4                Clear  2024-04-08 04:00:00ORD
#   DEST_WTH_name   DEST_WTH_datetime  DEST_WTH_temp  DEST_WTH_feelslike  \
# 0           ORD 2024-04-08 00:00:00          48.50               45.40
# 1           ORD 2024-04-08 01:00:00          49.20               46.20
# 2           ORD 2024-04-08 02:00:00          48.70               46.00
# 3           ORD 2024-04-08 03:00:00          47.70               44.90
# 4           ORD 2024-04-08 04:00:00          47.70               43.80
#
#    DEST_WTH_precip  DEST_WTH_precipprob DEST_WTH_preciptype  DEST_WTH_snow  \
# 0             0.00                    0                 NaN           0.00
# 1             0.00                    0                 NaN           0.00
# 2             0.00                    0                 NaN           0.00
# 3             0.00                    0                 NaN           0.00
# 4             0.00                    0                 NaN           0.00
#
#    DEST_WTH_windgust  DEST_WTH_windspeed  DEST_WTH_winddir  \
# 0              16.10                6.90               135
# 1              13.90                6.90               157
# 2              11.40                6.30               161
# 3              10.30                6.10               166
# 4              15.00                8.40               170
#
#    DEST_WTH_cloudcover  DEST_WTH_visibility  DEST_WTH_severerisk  \
# 0                 0.00                 9.90                   10
# 1                 0.00                 9.90                   10
# 2                 0.00                 9.90                   10
# 3                 0.00                 9.90                   10
# 4                 0.00                 9.90                   10
#
#   DEST_WTH_conditions           DEST_WTH_JOIN
# 0               Clear  2024-04-08 00:00:00ORD
# 1               Clear  2024-04-08 01:00:00ORD
# 2               Clear  2024-04-08 02:00:00ORD
# 3               Clear  2024-04-08 03:00:00ORD
# 4               Clear  2024-04-08 04:00:00ORD

# %%
# Join data set
merged_flight_weather = pd.merge(initial_predictions_dataset, org_weather_data, on='ORGIN_WTH_JOIN')
merged_flight_weather = pd.merge(merged_flight_weather, dst_weather_data, on='DEST_WTH_JOIN')

merged_flight_weather.head()
merged_flight_weather.shape
merged_flight_weather.columns
# Out:
#   FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  ARRIVAL STATUS  \
# 0       UA 1400                 UA                UA    ORD             NaN
# 1       AA 3402                 AA                MQ    ORD             NaN
# 2        B6 116                 B6                B6    JFK             NaN
# 3       DL 5182                 DL                9E    JFK             NaN
# 4        B6 656                 B6                B6    MCO             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late        SCH_DEP_TIME        SCH_ARR_TIME  \
# 0                              NaN 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1                              NaN 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2                              NaN 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3                              NaN 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4                              NaN 2024-04-10 13:35:00 2024-04-10 16:25:00
#
#    DAY_OF_WEEK DEST          ORGIN_WTH_JOIN           DEST_WTH_JOIN  \
# 0            3  SYR  2024-04-10 19:00:00ORD  2024-04-10 22:00:00SYR
# 1            3  SYR  2024-04-10 20:00:00ORD  2024-04-10 23:00:00SYR
# 2            3  SYR  2024-04-10 14:00:00JFK  2024-04-10 15:00:00SYR
# 3            3  SYR  2024-04-10 15:00:00JFK  2024-04-10 16:00:00SYR
# 4            3  SYR  2024-04-10 14:00:00MCO  2024-04-10 16:00:00SYR
#
#   ORGIN_WTH_name  ORGIN_WTH_datetime  ORGIN_WTH_temp  ORGIN_WTH_feelslike  \
# 0            ORD 2024-04-10 19:00:00           62.50                62.50
# 1            ORD 2024-04-10 20:00:00           61.90                61.90
# 2            JFK 2024-04-10 14:00:00           60.30                60.30
# 3            JFK 2024-04-10 15:00:00           64.10                64.10
# 4            MCO 2024-04-10 14:00:00           84.00                84.10
#
#    ORGIN_WTH_precip  ORGIN_WTH_precipprob ORGIN_WTH_preciptype  \
# 0              0.00                     0                  NaN
# 1              0.00                     0                  NaN
# 2              0.00                     0                  NaN
# 3              0.00                     0                  NaN
# 4              0.00                     0                  NaN
#
#    ORGIN_WTH_snow  ORGIN_WTH_windgust  ORGIN_WTH_windspeed  ORGIN_WTH_winddir  \
# 0            0.00               12.80                 9.50                 87
# 1            0.00               11.40                 9.70                 86
# 2            0.00               11.40                11.20                 42
# 3            0.00               10.30                 5.00                 42
# 4            0.00               28.80                18.10                160
#
#    ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  ORGIN_WTH_severerisk  \
# 0                 88.10                  9.90                    10
# 1                 88.10                  9.90                    10
# 2                 88.30                  9.90                    10
# 3                 29.50                  9.90                    10
# 4                 30.70                  9.90                    10
#
#   ORGIN_WTH_conditions DEST_WTH_name   DEST_WTH_datetime  DEST_WTH_temp  \
# 0     Partially cloudy           SYR 2024-04-10 22:00:00          58.70
# 1     Partially cloudy           SYR 2024-04-10 23:00:00          56.70
# 2     Partially cloudy           SYR 2024-04-10 15:00:00          62.80
# 3     Partially cloudy           SYR 2024-04-10 16:00:00          61.00
# 4     Partially cloudy           SYR 2024-04-10 16:00:00          61.00
#
#    DEST_WTH_feelslike  DEST_WTH_precip  DEST_WTH_precipprob  \
# 0               58.70             0.00                  100
# 1               56.70             0.01                  100
# 2               62.80             0.00                  100
# 3               61.00             0.09                  100
# 4               61.00             0.09                  100
#
#   DEST_WTH_preciptype  DEST_WTH_snow  DEST_WTH_windgust  DEST_WTH_windspeed  \
# 0                rain           0.00               3.40                3.20
# 1                rain           0.00               2.20                0.00
# 2                rain           0.00               8.10               16.00
# 3                rain           0.00              11.40                4.80
# 4                rain           0.00              11.40                4.80
#
#    DEST_WTH_winddir  DEST_WTH_cloudcover  DEST_WTH_visibility  \
# 0               342               100.00                 9.90
# 1                 4               100.00                 9.90
# 2               331                99.90                 9.80
# 3               341               100.00                 8.60
# 4               341               100.00                 8.60
#
#    DEST_WTH_severerisk DEST_WTH_conditions
# 0                   10      Rain, Overcast
# 1                   10      Rain, Overcast
# 2                   10      Rain, Overcast
# 3                   10      Rain, Overcast
# 4                   10      Rain, Overcast
# (51, 44)
# Index(['FLIGHT NUMBER', 'MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN',
#        'ARRIVAL STATUS', 'ARRIVAL STATUS_Prev_flight_early',
#        'ARRIVAL STATUS_Prev_flight_ontime', 'ARRIVAL STATUS_Prev_flight_late',
#        'SCH_DEP_TIME', 'SCH_ARR_TIME', 'DAY_OF_WEEK', 'DEST', 'ORGIN_WTH_JOIN',
#        'DEST_WTH_JOIN', 'ORGIN_WTH_name', 'ORGIN_WTH_datetime',
#        'ORGIN_WTH_temp', 'ORGIN_WTH_feelslike', 'ORGIN_WTH_precip',
#        'ORGIN_WTH_precipprob', 'ORGIN_WTH_preciptype', 'ORGIN_WTH_snow',
#        'ORGIN_WTH_windgust', 'ORGIN_WTH_windspeed', 'ORGIN_WTH_winddir',
#        'ORGIN_WTH_cloudcover', 'ORGIN_WTH_visibility', 'ORGIN_WTH_severerisk',
#        'ORGIN_WTH_conditions', 'DEST_WTH_name', 'DEST_WTH_datetime',
#        'DEST_WTH_temp', 'DEST_WTH_feelslike', 'DEST_WTH_precip',
#        'DEST_WTH_precipprob', 'DEST_WTH_preciptype', 'DEST_WTH_snow',
#        'DEST_WTH_windgust', 'DEST_WTH_windspeed', 'DEST_WTH_winddir',
#        'DEST_WTH_cloudcover', 'DEST_WTH_visibility', 'DEST_WTH_severerisk',
#        'DEST_WTH_conditions'],
#       dtype='object')

# %%
# Drop unnecessary columns
merged_flight_weather_updated = merged_flight_weather.drop(columns=['ORGIN_WTH_JOIN', 'DEST_WTH_JOIN', 'ORGIN_WTH_datetime', 'DEST_WTH_datetime', 'ORGIN_WTH_name', 'DEST_WTH_name'])

# %%
merged_flight_weather_updated.head()
# Out:
#   FLIGHT NUMBER MKT_UNIQUE_CARRIER OP_UNIQUE_CARRIER ORIGIN  ARRIVAL STATUS  \
# 0       UA 1400                 UA                UA    ORD             NaN
# 1       AA 3402                 AA                MQ    ORD             NaN
# 2        B6 116                 B6                B6    JFK             NaN
# 3       DL 5182                 DL                9E    JFK             NaN
# 4        B6 656                 B6                B6    MCO             NaN
#
#    ARRIVAL STATUS_Prev_flight_early  ARRIVAL STATUS_Prev_flight_ontime  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    ARRIVAL STATUS_Prev_flight_late        SCH_DEP_TIME        SCH_ARR_TIME  \
# 0                              NaN 2024-04-10 18:52:00 2024-04-10 21:47:00
# 1                              NaN 2024-04-10 19:59:00 2024-04-10 22:52:00
# 2                              NaN 2024-04-10 13:33:00 2024-04-10 14:50:00
# 3                              NaN 2024-04-10 14:55:00 2024-04-10 16:21:00
# 4                              NaN 2024-04-10 13:35:00 2024-04-10 16:25:00
#
#    DAY_OF_WEEK DEST  ORGIN_WTH_temp  ORGIN_WTH_feelslike  ORGIN_WTH_precip  \
# 0            3  SYR           62.50                62.50              0.00
# 1            3  SYR           61.90                61.90              0.00
# 2            3  SYR           60.30                60.30              0.00
# 3            3  SYR           64.10                64.10              0.00
# 4            3  SYR           84.00                84.10              0.00
#
#    ORGIN_WTH_precipprob ORGIN_WTH_preciptype  ORGIN_WTH_snow  \
# 0                     0                  NaN            0.00
# 1                     0                  NaN            0.00
# 2                     0                  NaN            0.00
# 3                     0                  NaN            0.00
# 4                     0                  NaN            0.00
#
#    ORGIN_WTH_windgust  ORGIN_WTH_windspeed  ORGIN_WTH_winddir  \
# 0               12.80                 9.50                 87
# 1               11.40                 9.70                 86
# 2               11.40                11.20                 42
# 3               10.30                 5.00                 42
# 4               28.80                18.10                160
#
#    ORGIN_WTH_cloudcover  ORGIN_WTH_visibility  ORGIN_WTH_severerisk  \
# 0                 88.10                  9.90                    10
# 1                 88.10                  9.90                    10
# 2                 88.30                  9.90                    10
# 3                 29.50                  9.90                    10
# 4                 30.70                  9.90                    10
#
#   ORGIN_WTH_conditions  DEST_WTH_temp  DEST_WTH_feelslike  DEST_WTH_precip  \
# 0     Partially cloudy          58.70               58.70             0.00
# 1     Partially cloudy          56.70               56.70             0.01
# 2     Partially cloudy          62.80               62.80             0.00
# 3     Partially cloudy          61.00               61.00             0.09
# 4     Partially cloudy          61.00               61.00             0.09
#
#    DEST_WTH_precipprob DEST_WTH_preciptype  DEST_WTH_snow  DEST_WTH_windgust  \
# 0                  100                rain           0.00               3.40
# 1                  100                rain           0.00               2.20
# 2                  100                rain           0.00               8.10
# 3                  100                rain           0.00              11.40
# 4                  100                rain           0.00              11.40
#
#    DEST_WTH_windspeed  DEST_WTH_winddir  DEST_WTH_cloudcover  \
# 0                3.20               342               100.00
# 1                0.00                 4               100.00
# 2               16.00               331                99.90
# 3                4.80               341               100.00
# 4                4.80               341               100.00
#
#    DEST_WTH_visibility  DEST_WTH_severerisk DEST_WTH_conditions
# 0                 9.90                   10      Rain, Overcast
# 1                 9.90                   10      Rain, Overcast
# 2                 9.80                   10      Rain, Overcast
# 3                 8.60                   10      Rain, Overcast
# 4                 8.60                   10      Rain, Overcast

# %%
merged_flight_weather_updated.columns
# Out:
# Index(['FLIGHT NUMBER', 'MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN',
#        'ARRIVAL STATUS', 'ARRIVAL STATUS_Prev_flight_early',
#        'ARRIVAL STATUS_Prev_flight_ontime', 'ARRIVAL STATUS_Prev_flight_late',
#        'SCH_DEP_TIME', 'SCH_ARR_TIME', 'DAY_OF_WEEK', 'DEST', 'ORGIN_WTH_temp',
#        'ORGIN_WTH_feelslike', 'ORGIN_WTH_precip', 'ORGIN_WTH_precipprob',
#        'ORGIN_WTH_preciptype', 'ORGIN_WTH_snow', 'ORGIN_WTH_windgust',
#        'ORGIN_WTH_windspeed', 'ORGIN_WTH_winddir', 'ORGIN_WTH_cloudcover',
#        'ORGIN_WTH_visibility', 'ORGIN_WTH_severerisk', 'ORGIN_WTH_conditions',
#        'DEST_WTH_temp', 'DEST_WTH_feelslike', 'DEST_WTH_precip',
#        'DEST_WTH_precipprob', 'DEST_WTH_preciptype', 'DEST_WTH_snow',
#        'DEST_WTH_windgust', 'DEST_WTH_windspeed', 'DEST_WTH_winddir',
#        'DEST_WTH_cloudcover', 'DEST_WTH_visibility', 'DEST_WTH_severerisk',
#        'DEST_WTH_conditions'],
#       dtype='object')

# %%
columns_to_drop = ['FLIGHT NUMBER', 'ARRIVAL STATUS', 'ARRIVAL STATUS_Prev_flight_early', 'ARRIVAL STATUS_Prev_flight_ontime', 'ARRIVAL STATUS_Prev_flight_late', 'ORGIN_WTH_feelslike',
                    'ORGIN_WTH_windgust', 'DEST_WTH_feelslike', 'DEST_WTH_windgust',
                    'DEST', 'DEST_WTH_preciptype', 'ORGIN_WTH_preciptype',
                    'DEST_WTH_conditions', 'ORGIN_WTH_conditions']
flight_weather_data_updated =  merged_flight_weather_updated.drop(columns = columns_to_drop)
flight_weather_data_updated.shape
flight_weather_data_updated.columns
# Out:
# (51, 24)
# Index(['MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'SCH_DEP_TIME',
#        'SCH_ARR_TIME', 'DAY_OF_WEEK', 'ORGIN_WTH_temp', 'ORGIN_WTH_precip',
#        'ORGIN_WTH_precipprob', 'ORGIN_WTH_snow', 'ORGIN_WTH_windspeed',
#        'ORGIN_WTH_winddir', 'ORGIN_WTH_cloudcover', 'ORGIN_WTH_visibility',
#        'ORGIN_WTH_severerisk', 'DEST_WTH_temp', 'DEST_WTH_precip',
#        'DEST_WTH_precipprob', 'DEST_WTH_snow', 'DEST_WTH_windspeed',
#        'DEST_WTH_winddir', 'DEST_WTH_cloudcover', 'DEST_WTH_visibility',
#        'DEST_WTH_severerisk'],
#       dtype='object')

# %%
flight_weather_data_updated.to_csv('./test_data/Test_Merged_Data.csv', index=False)
